# %%
import pandas as pd

# %%
train = pd.read_csv(r'F:\Thai_speech\kaggle_competition\HackOWASP ML Contest\train_ml.csv',index_col='id')
test = pd.read_csv(r'F:\Thai_speech\kaggle_competition\HackOWASP ML Contest\test_ml.csv',index_col='id')

# %%
train
# Out:
#       feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# id
# 1          1.94       0.71       4.72      -1.88      -3.23       1.94
# 2          2.92       1.46       0.13      -8.12      -5.07       2.92
# 3         -1.67      -1.01      -0.41      10.73      -3.50      -1.67
# 4          3.66      -3.37      -0.87     -10.04      -2.77       3.66
# 5          9.68      -4.61       0.45       5.01       0.25       9.68
# ...         ...        ...        ...        ...        ...        ...
# 7995       5.26       1.58      -1.97     -10.42      -3.91       5.26
# 7996       5.93       2.94      -3.88      -4.67      -3.14        NaN
# 7997      -1.64       0.60      -0.18      -7.08      -1.37      -1.64
# 7998      -4.77      -4.92       6.02       9.67       0.91      -4.77
# 7999       4.88      -3.04       1.72      -5.73       4.53       4.88
#
#       feature_7  feature_8  feature_9  feature_10  ...  feature_92  \
# id                                                 ...
# 1        -11.19      -3.64      -0.13       -4.11  ...        3.21
# 2         -7.98      -0.47       0.83       -1.76  ...        2.04
# 3          0.04       0.29       0.51        2.37  ...       -6.27
# 4          0.29       2.11      -1.27        0.26  ...       -2.66
# 5          4.42      -3.54       0.40        1.88  ...       -6.67
# ...         ...        ...        ...         ...  ...         ...
# 7995     -10.19      -1.05        NaN       -4.22  ...        0.35
# 7996       0.60      -1.13      -0.29       -1.72  ...        2.52
# 7997      -7.54       2.77      -0.55       -1.09  ...       -0.21
# 7998      -5.79       2.10      -0.53        1.57  ...       -3.08
# 7999      -7.06       2.71       1.02       -3.68  ...       -2.51
#
#       feature_93  feature_94  feature_95  feature_96  feature_97  feature_98  \
# id
# 1          -0.21        0.68        1.78        4.39       -4.11       -4.11
# 2          -2.60        3.27        0.91        1.68       -1.76       -1.76
# 3           3.64       -3.11        1.63       12.72        2.37        2.37
# 4           3.42        2.75       -0.13        0.88        0.26        0.26
# 5          -0.81       -3.76        0.08       -2.14        1.88        1.88
# ...          ...         ...         ...         ...         ...         ...
# 7995        2.74       -0.72       -0.45        4.06       -4.22       -4.22
# 7996       -1.93        3.92       -1.25       -2.21       -1.72       -1.72
# 7997       -0.28        0.56       -1.16        1.59       -1.09         NaN
# 7998       -4.02       -5.22       -0.41        0.20        1.57        1.57
# 7999        0.06       -0.72       -2.63      -11.01       -3.68       -3.68
#
#       feature_99  feature_100  target
# id
# 1           0.71        -1.88       1
# 2           1.46        -8.12      18
# 3          -1.01        10.73      13
# 4          -3.37       -10.04       9
# 5          -4.61         5.01       7
# ...          ...          ...     ...
# 7995        1.58       -10.42      19
# 7996        2.94        -4.67      12
# 7997        0.60        -7.08       1
# 7998       -4.92         9.67       2
# 7999       -3.04        -5.73      19
#
# [7999 rows x 101 columns]

# %%
test
# Out:
#          f1    f2    f3     f4    f5    f6     f7    f8    f9   f10  ...  \
# id                                                                   ...
# 8001  -4.63 -0.45 -1.63  11.66  0.82 -4.63 -15.42 -0.03 -0.13 -1.04  ...
# 8002  -6.95  1.73  1.91   3.38 -0.15 -6.95   3.62 -1.99 -0.70  2.80  ...
# 8003  -4.12  1.44  2.07   1.26  0.86 -4.12  -1.86  6.05 -0.08  1.70  ...
# 8004   2.36  0.59 -3.07  -1.62 -0.12  2.36  -2.18  0.29   NaN -3.00  ...
# 8005  -1.45 -2.19  1.32   9.16  0.93 -1.45  -8.22 -0.59  1.25 -2.37  ...
# ...     ...   ...   ...    ...   ...   ...    ...   ...   ...   ...  ...
# 9996  -1.05 -0.85  2.95   0.45 -1.08 -1.05  -4.34 -2.84   NaN  1.87  ...
# 9997   5.59  2.98  1.49   2.35 -1.15  5.59   2.70  5.40 -0.03 -0.04  ...
# 9998  -3.51 -0.27 -2.14 -10.63 -0.61 -3.51  -2.43 -1.48 -0.55  0.85  ...
# 9999   3.90 -0.89  1.07  -2.09  1.38  3.90  -2.66 -0.80  1.90 -1.77  ...
# 10000  6.92  0.04 -3.23  -3.24 -2.15  6.92  12.77 -1.70  0.34 -2.31  ...
#
#         f91   f92   f93   f94   f95    f96   f97   f98   f99   f100
# id
# 8001  -2.12  2.74  1.12 -0.10  0.73  -1.49 -1.04 -1.04 -0.45  11.66
# 8002  -0.78  3.10  3.07 -5.73  1.03  15.23  2.80  2.80  1.73   3.38
# 8003   2.37  3.36 -3.04  1.08 -0.65   8.02  1.70  1.70  1.44   1.26
# 8004   2.34  2.57 -0.21  0.04  0.89  -5.77 -3.00 -3.00  0.59  -1.62
# 8005   0.92 -1.56 -1.50 -6.47 -0.13   3.71 -2.37 -2.37 -2.19   9.16
# ...     ...   ...   ...   ...   ...    ...   ...   ...   ...    ...
# 9996   1.44  3.33  0.08 -6.18  0.02   6.50  1.87  1.87 -0.85   0.45
# 9997  -0.39  2.84  1.38  1.72  1.60   1.89 -0.04 -0.04  2.98   2.35
# 9998  -1.79  2.92  2.27  1.14 -0.05   1.29  0.85  0.85 -0.27 -10.63
# 9999  -0.62 -0.60  1.40  2.20   NaN  -3.86 -1.77 -1.77 -0.89  -2.09
# 10000  0.72  0.93 -3.40 -2.53  0.54  -4.90 -2.31 -2.31  0.04  -3.24
#
# [2000 rows x 100 columns]

# %%
mapping = {f'f{i}': f'feature_{i}' for i in range(1, 101)}
test_renamed = test.rename(columns=mapping)
test_renamed
# Out:
#        feature_1  feature_2  feature_3  feature_4  feature_5  feature_6  \
# id
# 8001       -4.63      -0.45      -1.63      11.66       0.82      -4.63
# 8002       -6.95       1.73       1.91       3.38      -0.15      -6.95
# 8003       -4.12       1.44       2.07       1.26       0.86      -4.12
# 8004        2.36       0.59      -3.07      -1.62      -0.12       2.36
# 8005       -1.45      -2.19       1.32       9.16       0.93      -1.45
# ...          ...        ...        ...        ...        ...        ...
# 9996       -1.05      -0.85       2.95       0.45      -1.08      -1.05
# 9997        5.59       2.98       1.49       2.35      -1.15       5.59
# 9998       -3.51      -0.27      -2.14     -10.63      -0.61      -3.51
# 9999        3.90      -0.89       1.07      -2.09       1.38       3.90
# 10000       6.92       0.04      -3.23      -3.24      -2.15       6.92
#
#        feature_7  feature_8  feature_9  feature_10  ...  feature_91  \
# id                                                  ...
# 8001      -15.42      -0.03      -0.13       -1.04  ...       -2.12
# 8002        3.62      -1.99      -0.70        2.80  ...       -0.78
# 8003       -1.86       6.05      -0.08        1.70  ...        2.37
# 8004       -2.18       0.29        NaN       -3.00  ...        2.34
# 8005       -8.22      -0.59       1.25       -2.37  ...        0.92
# ...          ...        ...        ...         ...  ...         ...
# 9996       -4.34      -2.84        NaN        1.87  ...        1.44
# 9997        2.70       5.40      -0.03       -0.04  ...       -0.39
# 9998       -2.43      -1.48      -0.55        0.85  ...       -1.79
# 9999       -2.66      -0.80       1.90       -1.77  ...       -0.62
# 10000      12.77      -1.70       0.34       -2.31  ...        0.72
#
#        feature_92  feature_93  feature_94  feature_95  feature_96  feature_97  \
# id
# 8001         2.74        1.12       -0.10        0.73       -1.49       -1.04
# 8002         3.10        3.07       -5.73        1.03       15.23        2.80
# 8003         3.36       -3.04        1.08       -0.65        8.02        1.70
# 8004         2.57       -0.21        0.04        0.89       -5.77       -3.00
# 8005        -1.56       -1.50       -6.47       -0.13        3.71       -2.37
# ...           ...         ...         ...         ...         ...         ...
# 9996         3.33        0.08       -6.18        0.02        6.50        1.87
# 9997         2.84        1.38        1.72        1.60        1.89       -0.04
# 9998         2.92        2.27        1.14       -0.05        1.29        0.85
# 9999        -0.60        1.40        2.20         NaN       -3.86       -1.77
# 10000        0.93       -3.40       -2.53        0.54       -4.90       -2.31
#
#        feature_98  feature_99  feature_100
# id
# 8001        -1.04       -0.45        11.66
# 8002         2.80        1.73         3.38
# 8003         1.70        1.44         1.26
# 8004        -3.00        0.59        -1.62
# 8005        -2.37       -2.19         9.16
# ...           ...         ...          ...
# 9996         1.87       -0.85         0.45
# 9997        -0.04        2.98         2.35
# 9998         0.85       -0.27       -10.63
# 9999        -1.77       -0.89        -2.09
# 10000       -2.31        0.04        -3.24
#
# [2000 rows x 100 columns]

# %% [markdown]
# #### Correlation Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = train.corr()
corr_with_target = corr_matrix['target'].drop('target')
selected_corr = corr_with_target[abs(corr_with_target) > 0.03]
df_train_selected = train[selected_corr.index.tolist() + ['target']]

# %%
print(df_train_selected.isnull().sum())
# Out:
# feature_7     158
# feature_12    161
# feature_16    149
# feature_17    172
# feature_18    164
# feature_19    161
# feature_20    155
# feature_21    150
# feature_23    132
# feature_30    124
# feature_31    175
# feature_32    170
# feature_37    181
# feature_38    152
# feature_43    161
# feature_45    176
# feature_53    141
# feature_54    129
# feature_56    163
# feature_61    153
# feature_63    170
# feature_64    156
# feature_68    152
# feature_69    179
# feature_77    164
# feature_79    158
# feature_84    134
# feature_86    187
# feature_90    164
# feature_92    157
# feature_94    170
# target          0
# dtype: int64

# %%
# เติมด้วยค่าเฉลี่ยของแต่ละ column
df_train_filled = df_train_selected.fillna(df_train_selected.mean())
df_train_filled
# Out:
#       feature_7  feature_12  feature_16  feature_17  feature_18  feature_19  \
# id
# 1        -11.19    0.069703        3.21        2.48      -11.19       -0.33
# 2         -7.98   -0.460000        2.04       -5.10       -7.98       -3.78
# 3          0.04    3.800000       -6.27       11.00        0.04       -3.65
# 4          0.29    2.460000       -2.66       -4.90        0.29       -1.61
# 5          4.42   -2.010000       -6.67        6.24        4.42        0.22
# ...         ...         ...         ...         ...         ...         ...
# 7995     -10.19   -1.610000        0.35       -4.71      -10.19        2.59
# 7996       0.60    1.340000        2.52       -1.17        0.60       -1.42
# 7997      -7.54    2.770000       -0.21      -11.51       -7.54        1.07
# 7998      -5.79    2.710000       -3.08       -5.72       -5.79        3.82
# 7999      -7.06   -3.430000       -2.51       -4.64       -7.06        2.45
#
#       feature_20  feature_21  feature_23  feature_30  ...  feature_68  \
# id                                                    ...
# 1           2.48       11.54    0.960000        0.68  ...       -2.66
# 2          -5.10        4.16   -0.460000        3.27  ...       -2.53
# 3          11.00      -13.89    3.800000       -3.11  ...       -0.27
# 4          -4.90        0.53    2.460000        2.75  ...        2.87
# 5           6.24       -9.54   -2.010000       -3.76  ...        0.37
# ...          ...         ...         ...         ...  ...         ...
# 7995       -4.71        6.71    0.069164       -0.72  ...        3.69
# 7996       -1.17       -2.75    1.340000        3.92  ...       -3.28
# 7997      -11.51        3.51    2.770000        0.56  ...        1.28
# 7998       -5.72       -0.08    2.710000       -5.22  ...       -3.85
# 7999       -4.64       10.02   -3.430000       -0.72  ...        2.73
#
#       feature_69  feature_77  feature_79  feature_84  feature_86  feature_90  \
# id
# 1          -2.11        2.38    0.680000       -2.11       -2.11       -2.66
# 2          -2.50       -1.54    3.270000       -2.50       -2.50       -2.53
# 3           3.07       -1.67   -3.110000        3.07        3.07       -0.27
# 4           0.44       -3.09    2.750000        0.44        0.44        2.87
# 5           4.94       -3.80   -3.760000        4.94        4.94        0.37
# ...          ...         ...         ...         ...         ...         ...
# 7995       -0.13       -2.73    0.076638       -0.13       -0.13        3.69
# 7996        3.60       -3.74    3.920000        3.60        3.60       -3.28
# 7997       -0.83       -4.76    0.560000       -0.83       -0.83        1.28
# 7998       -0.68       -0.72   -5.220000       -0.68       -0.68       -3.85
# 7999       -2.28       -0.70   -0.720000       -2.28       -2.28        2.73
#
#       feature_92  feature_94  target
# id
# 1           3.21        0.68       1
# 2           2.04        3.27      18
# 3          -6.27       -3.11      13
# 4          -2.66        2.75       9
# 5          -6.67       -3.76       7
# ...          ...         ...     ...
# 7995        0.35       -0.72      19
# 7996        2.52        3.92      12
# 7997       -0.21        0.56       1
# 7998       -3.08       -5.22       2
# 7999       -2.51       -0.72      19
#
# [7999 rows x 32 columns]

# %%
target_column = 'target'
feature_columns = [col for col in df_train_selected.columns if col != target_column]
df_test_selected = test_renamed[feature_columns]
df_test_filled = df_test_selected.fillna(df_test_selected.mean())
df_test_filled
# Out:
#        feature_7  feature_12  feature_16  feature_17  feature_18  feature_19  \
# id
# 8001      -15.42        0.62        2.74        8.05      -15.42        3.74
# 8002        3.62       -1.64        3.10       11.41        3.62        1.50
# 8003       -1.86        0.46        3.36      -17.47       -1.86       -5.64
# 8004       -2.18        0.41        2.57       -3.59       -2.18        0.89
# 8005       -8.22        1.02       -1.56        8.54       -8.22        3.46
# ...          ...         ...         ...         ...         ...         ...
# 9996       -4.34       -2.87        3.33      -17.92       -4.34        4.42
# 9997        2.70       -0.62        2.84       -2.07        2.70       -4.58
# 9998       -2.43       -1.30        2.92       -2.37       -2.43        3.42
# 9999       -2.66        1.23       -0.60        5.06       -2.66        1.20
# 10000      12.77       -1.33        0.93       -1.25       12.77        0.65
#
#        feature_20  feature_21  feature_23  feature_30  ...  feature_64  \
# id                                                     ...
# 8001         8.05   -5.850000        0.62       -0.10  ...       -2.09
# 8002        11.41   -7.630000       -1.64       -5.73  ...        0.43
# 8003       -17.47   -2.350000        0.46        1.08  ...        0.71
# 8004        -3.59    0.263594        0.41        0.04  ...       -3.77
# 8005         8.54    2.500000        1.02       -6.47  ...       -0.43
# ...           ...         ...         ...         ...  ...         ...
# 9996       -17.92    2.450000       -2.87       -6.18  ...       -1.82
# 9997        -2.07   -5.300000       -0.62        1.72  ...       -2.16
# 9998        -2.37   -4.280000       -1.30        1.14  ...       -1.45
# 9999         5.06    3.460000        1.23        2.20  ...       -0.54
# 10000       -1.25    3.560000       -1.33       -2.53  ...        1.52
#
#        feature_68  feature_69  feature_77  feature_79  feature_84  feature_86  \
# id
# 8001    -3.670000        4.32       -2.09       -0.10   -0.009422    4.320000
# 8002    -4.230000        2.16        0.43       -5.73    2.160000    2.160000
# 8003     2.440000       -1.76        0.71        1.08   -1.760000   -1.760000
# 8004    -2.710000       -1.66       -3.77        0.04   -1.660000   -1.660000
# 8005    -1.140000        4.34       -0.43       -6.47    4.340000    4.340000
# ...           ...         ...         ...         ...         ...         ...
# 9996    -1.490000        1.49       -1.82       -6.18    1.490000    1.490000
# 9997     0.570000       -2.87       -2.16        1.72   -2.870000   -0.011867
# 9998     0.049606        1.43       -1.45        1.14    1.430000    1.430000
# 9999     1.770000        2.40       -0.54        2.20    2.400000    2.400000
# 10000   -2.410000        0.24        1.52       -2.53    0.240000    0.240000
#
#        feature_90  feature_92  feature_94
# id
# 8001        -3.67        2.74       -0.10
# 8002        -4.23        3.10       -5.73
# 8003         2.44        3.36        1.08
# 8004        -2.71        2.57        0.04
# 8005        -1.14       -1.56       -6.47
# ...           ...         ...         ...
# 9996        -1.49        3.33       -6.18
# 9997         0.57        2.84        1.72
# 9998        -1.70        2.92        1.14
# 9999         1.77       -0.60        2.20
# 10000       -2.41        0.93       -2.53
#
# [2000 rows x 31 columns]

# %% [markdown]
# #### Model Development

# %%
X_train =
